# %%
import pandas as pd

# %%
employees = pd.DataFrame({
    "EmpID": [1, 2, 3],
    "Name": ["Alice", "Bob", "Charlie"],
    "DeptID": [10, 20, 30]
})

# %%
employees
# Out:
#    EmpID     Name  DeptID
# 0      1    Alice      10
# 1      2      Bob      20
# 2      3  Charlie      30

# %%
departments = pd.DataFrame({
    "DeptID": [10, 20, 40],
    "DeptName": ["HR", "Engineering", "Marketing"]
})

# %%
departments
# Out:
#    DeptID     DeptName
# 0      10           HR
# 1      20  Engineering
# 2      40    Marketing

# %%
pd.merge(employees, departments , on = "DeptID")#inner join
# Out:
#    EmpID   Name  DeptID     DeptName
# 0      1  Alice      10           HR
# 1      2    Bob      20  Engineering

# %%
pd.merge(employees, departments , on = "DeptID" , how = "left")#left join
# Out:
#    EmpID     Name  DeptID     DeptName
# 0      1    Alice      10           HR
# 1      2      Bob      20  Engineering
# 2      3  Charlie      30          NaN

# %%
pd.merge(employees, departments , on = "DeptID", how = "right")#right join
# Out:
#    EmpID   Name  DeptID     DeptName
# 0    1.0  Alice      10           HR
# 1    2.0    Bob      20  Engineering
# 2    NaN    NaN      40    Marketing

# %%
pd.merge(employees, departments , on = "DeptID", how = "outer")
# Out:
#    EmpID     Name  DeptID     DeptName
# 0    1.0    Alice      10           HR
# 1    2.0      Bob      20  Engineering
# 2    3.0  Charlie      30          NaN
# 3    NaN      NaN      40    Marketing

# %%
df1 = pd.DataFrame({ "Name" : ["Rutuja", "Anuj", "Yukta" , "Sumit"] ,
                    "Roll no" : [12, 13, 14, 15]})
df2 = pd.DataFrame({ "Name" : ["Disha" , "Tanmay"],
                    "Roll no" : [15,16]})

# %%
df1
# Out:
#      Name  Roll no
# 0  Rutuja       12
# 1    Anuj       13
# 2   Yukta       14
# 3   Sumit       15

# %%
df2
# Out:
#      Name  Roll no
# 0   Disha       15
# 1  Tanmay       16

# %%
pd.concat([df1,df2]) ##here by default axis is 0 always
# Out:
#      Name  Roll no
# 0  Rutuja       12
# 1    Anuj       13
# 2   Yukta       14
# 3   Sumit       15
# 0   Disha       15
# 1  Tanmay       16

# %%
pd.concat([df1,df2] , axis = 1)
# Out:
#      Name  Roll no    Name  Roll no
# 0  Rutuja       12   Disha     15.0
# 1    Anuj       13  Tanmay     16.0
# 2   Yukta       14     NaN      NaN
# 3   Sumit       15     NaN      NaN
